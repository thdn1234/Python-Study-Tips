# %%
#データ収集 vs Crolling
#Website内容を読み込む（Crollingの一部）=> データ収集
#Hyperlinkを認識し、URLリストを持ってくる（スケジュール的に）=> Crolling

# %%
# !pip install requests
# 小さいブラウザでWEBSiteを読み込む

# %%
# !pip install tqdm
# 反復で長い作業でいい

# %%
# データ収集しても大丈夫か確認
# 1.robots規約

# https://www.seoul.go.kr/robots.txt
# User-agent: *
# Allow: /

# Sitemap: https://www.seoul.go.kr/sitemap.xml　（サイトの構造を見れる）　

# http://www.naver.com/robots.txt
# User-agent: *
# Disallow: / (サイト収集不可能)
# Allow : /$ （$はMainページだけ可能の意味）

# https://ko.wikipedia.org/robots.txt

# 2.著作権確認

# 3.無理なネットワーク要請は止める

# %%
import pandas as pd
import numpy as np

# %%
url = "http://www.seoul.go.kr/coronaV/coronaStatus.do"
url
# Out:
# 'http://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
table = pd.read_html(url)

# %%
len(table)
# Out:
# 4

# %%
table[0]
# Out:
#    종로구   중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  노원구  은평구 서대문구
# 0  152  146  278  259  241   361  397  517  230  365  536  443  307
# 1   +3   +5   +4   +6   +7    +3  +21   +4   +3   +3   +7  +11   +5
# 2  마포구  양천구  강서구  구로구  금천구  영등포구  동작구  관악구  서초구  강남구  송파구  강동구   기타
# 3  363  378  732  321  148   366  486  632  571  600  716  331  787
# 4  +10  +10  +21  +12   +3    +4   +8  +17  +10  +10   +3  +10  +14

# %%
table[1]
# Out:
#      종로구   중구  용산구  성동구  광진구 동대문구
# 0    152  146  278  259  241  361
# 1     +3   +5   +4   +6   +7   +3
# 2    중랑구  성북구  강북구  도봉구  노원구  은평구
# 3    397  517  230  365  536  443
# 4    +21   +4   +3   +3   +7  +11
# 5   서대문구  마포구  양천구  강서구  구로구  금천구
# 6    307  363  378  732  321  148
# 7     +5  +10  +10  +21  +12   +3
# 8   영등포구  동작구  관악구  서초구  강남구  송파구
# 9    366  486  632  571  600  716
# 10    +4   +8  +17  +10  +10   +3
# 11   강동구   기타  NaN  NaN  NaN  NaN
# 12   331  787  NaN  NaN  NaN  NaN
# 13   +10  +14  NaN  NaN  NaN  NaN

# %%
df = table[3]
df.head()
# Out:
# Empty DataFrame
# Columns: [연번, 환자, 확진일, 거주지, 여행력, 접촉력, 퇴원현황]
# Index: []

# %%
#　11月以後内容が表示されません。

# %%
# 11以後のデータ公開方式変更

import requests

url = "https://news.seoul.go.kr"

# %%
# f-string(sample)
url = "https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw=1"
# url = f"{url}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc"
url = f"{url}&start=0&length=100"
# "&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1606633538547"
url
# Out:
# 'https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw=1&start=0&length=100'

# %%
# # f-string
# url = "https://news.seoul.go.kr/api/27/getCorona19Route/get_route_ajax.php?draw=1"
# # url = f"{url}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc&"
# url = f"{url}&start=0&length=100"
# # "&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1607236939739"
# url

# %%
response = requests.get(url)
data_json = response.json()
pd.DataFrame(data_json["data"])
# Out:
#                                    0      1       2     3  4          5  \
# 0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -   감염경로 조사중
# 1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -   감염경로 조사중
# 2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -   감염경로 조사중
# 3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -   감염경로 조사중
# 4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -   감염경로 조사중
# ..                               ...    ...     ...   ... ..        ...
# 95  <p class='corona19_no'>10568</p>  38380  12.07.   양천구  -  기타 확진자 접촉
# 96  <p class='corona19_no'>10567</p>  38342  12.07.  서대문구  -   감염경로 조사중
# 97  <p class='corona19_no'>10566</p>  38191  12.07.   마포구  -  기타 확진자 접촉
# 98  <p class='corona19_no'>10565</p>  38193  12.07.   마포구  -   감염경로 조사중
# 99  <p class='corona19_no'>10564</p>  38306  12.07.   성동구  -  기타 확진자 접촉
#
#                           6
# 0          <b class=''></b>
# 1          <b class=''></b>
# 2          <b class=''></b>
# 3          <b class=''></b>
# 4          <b class=''></b>
# ..                      ...
# 95  <b class='status2'></b>
# 96  <b class='status2'></b>
# 97  <b class='status2'></b>
# 98  <b class='status2'></b>
# 99  <b class='status2'></b>
#
# [100 rows x 7 columns]

# %%
records_total = data_json["recordsTotal"]
records_total
# Out:
# 10663

# %%
end_page = round(records_total / 100) +1
end_page
# Out:
# 108

# %%
data = data_json["data"]

# %%
data
# Out:
# [["<p class='corona19_no'>10663</p>",
#   '38379',
#   '12.07.',
#   '양천구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10662</p>",
#   '38370',
#   '12.07.',
#   '강서구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10661</p>",
#   '38419',
#   '12.07.',
#   '강서구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10660</p>",
#   '38418',
#   '12.07.',
#   '강서구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10659</p>",
#   '38558',
#   '12.07.',
#   '광진구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10658</p>",
#   '38399',
#   '12.07.',
#   '타시도',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10657</p>",
#   '38414',
#   '12.07.',
#   '중랑구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10656</p>",
#   '38373',
#   '12.07.',
#   '강서구',
#   '-',
#   '마포구 홍대새교회관련',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10655</p>",
#   '38325',
#   '12.07.',
#   '서대문구',
#   '호주',
#   '해외 유입',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10654</p>",
#   '38237',
#   '12.07.',
#   '성북구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10653</p>",
#   '38278',
#   '12.07.',
#   '동대문구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10652</p>",
#   '38250',
#   '12.07.',
#   '구로구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10651</p>",
#   '38445',
#   '12.07.',
#   '타시도',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10650</p>",
#   '38456',
#   '12.07.',
#   '타시도',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10649</p>",
#   '38561',
#   '12.07.',
#   '서초구',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10648</p>",
#   '38384',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10647</p>",
#   '38382',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10646</p>",
#   '38381',
#   '12.07.',
#   '강서구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10645</p>",
#   '38163',
#   '12.07.',
#   '강남구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10644</p>",
#   '38595',
#   '12.07.',
#   '강동구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10643</p>",
#   '38436',
#   '12.07.',
#   '노원구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10642</p>",
#   '38454',
#   '12.07.',
#   '강동구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10641</p>",
#   '38452',
#   '12.07.',
#   '강동구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10640</p>",
#   '38449',
#   '12.07.',
#   '강동구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10639</p>",
#   '38447',
#   '12.07.',
#   '중랑구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10638</p>",
#   '38444',
#   '12.07.',
#   '마포구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10637</p>",
#   '38253',
#   '12.07.',
#   '구로구',
#   '-',
#   '종로구 소재 파고다타운 관련',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10636</p>",
#   '38488',
#   '12.07.',
#   '구로구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10635</p>",
#   '38430',
#   '12.07.',
#   '관악구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10634</p>",
#   '38431',
#   '12.07.',
#   '관악구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10633</p>",
#   '38338',
#   '12.07.',
#   '서초구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10632</p>",
#   '38335',
#   '12.07.',
#   '용산구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10631</p>",
#   '38188',
#   '12.07.',
#   '마포구',
#   '-',
#   '감염경로 조사중',
#   "<b class=''></b>"],
#  ["<p class='corona19_no'>10630</p>",
#   '38162',
#   '12.07.',
#   '영등포구',
#   '-',
#   '마포구 홈쇼핑회사 관련',
#   "<b class='status2'>사망</b>"],
#  ["<p class='corona19_no'>10629</p>",
#   '38593',
#   '12.07.',
#   '타시도',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10628</p>",
#   '38443',
#   '12.07.',
#   '구로구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10627</p>",
#   '38440',
#   '12.07.',
#   '성동구',
#   '미국',
#   '해외 유입',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10626</p>",
#   '38446',
#   '12.07.',
#   '성동구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10625</p>",
#   '38541',
#   '12.07.',
#   '타시도',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10624</p>",
#   '38542',
#   '12.07.',
#   '타시도',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10623</p>",
#   '38318',
#   '12.07.',
#   '강동구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10622</p>",
#   '38317',
#   '12.07.',
#   '강동구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10621</p>",
#   '38322',
#   '12.07.',
#   '강동구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10620</p>",
#   '38289',
#   '12.07.',
#   '강동구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10619</p>",
#   '38288',
#   '12.07.',
#   '강동구',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10618</p>",
#   '38285',
#   '12.07.',
#   '강동구',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10617</p>",
#   '38555',
#   '12.07.',
#   '중랑구',
#   '-',
#   '중랑구 실내 체육시설 Ⅱ 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10616</p>",
#   '38450',
#   '12.07.',
#   '중랑구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10615</p>",
#   '38560',
#   '12.07.',
#   '중랑구',
#   '-',
#   '중랑구 소재 병원 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10614</p>",
#   '38562',
#   '12.07.',
#   '중랑구',
#   '-',
#   '중랑구 소재 병원 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10613</p>",
#   '38556',
#   '12.07.',
#   '중랑구',
#   '-',
#   '중랑구 소재 병원 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10612</p>",
#   '38549',
#   '12.07.',
#   '중랑구',
#   '-',
#   '노원구청 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10611</p>",
#   '38340',
#   '12.07.',
#   '양천구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10610</p>",
#   '38544',
#   '12.07.',
#   '중랑구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10609</p>",
#   '38423',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10608</p>",
#   '38249',
#   '12.07.',
#   '종로구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10607</p>",
#   '38421',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10606</p>",
#   '38548',
#   '12.07.',
#   '중랑구',
#   '-',
#   '중구 콜센터 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10605</p>",
#   '38545',
#   '12.07.',
#   '중랑구',
#   '-',
#   '종로구 소재 파고다타운 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10604</p>",
#   '38547',
#   '12.07.',
#   '중랑구',
#   '-',
#   '종로구 소재 파고다타운 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10603</p>",
#   '38411',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10602</p>",
#   '38406',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10601</p>",
#   '38396',
#   '12.07.',
#   '강서구',
#   '-',
#   '강서구 댄스교습관련 시설',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10600</p>",
#   '38404',
#   '12.07.',
#   '강남구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10599</p>",
#   '38258',
#   '12.07.',
#   '중구',
#   '-',
#   '중구 소재 시장 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10598</p>",
#   '38259',
#   '12.07.',
#   '중구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10597</p>",
#   '38298',
#   '12.07.',
#   '광진구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10596</p>",
#   '38297',
#   '12.07.',
#   '광진구',
#   '-',
#   '종로구 소재 파고다타운 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10595</p>",
#   '38296',
#   '12.07.',
#   '광진구',
#   '-',
#   '중랑구 실내 체육시설 Ⅱ 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10594</p>",
#   '38389',
#   '12.07.',
#   '강서구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10593</p>",
#   '38387',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10592</p>",
#   '38385',
#   '12.07.',
#   '강서구',
#   '-',
#   '관악구 소재 음식점 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10591</p>",
#   '38281',
#   '12.07.',
#   '영등포구',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10590</p>",
#   '38261',
#   '12.07.',
#   '중구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10589</p>",
#   '38286',
#   '12.07.',
#   '타시도',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10588</p>",
#   '38435',
#   '12.07.',
#   '성동구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10587</p>",
#   '38264',
#   '12.07.',
#   '중구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10586</p>",
#   '38246',
#   '12.07.',
#   '중구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10585</p>",
#   '38378',
#   '12.07.',
#   '강서구',
#   '-',
#   '강서구 댄스교습관련 시설',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10584</p>",
#   '38376',
#   '12.07.',
#   '강서구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10583</p>",
#   '38367',
#   '12.07.',
#   '강서구',
#   '-',
#   '강서구 댄스교습관련 시설',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10582</p>",
#   '38365',
#   '12.07.',
#   '강서구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10581</p>",
#   '38358',
#   '12.07.',
#   '강서구',
#   '-',
#   '강서구 소재 댄스교습시설 연관 병원',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10580</p>",
#   '38591',
#   '12.07.',
#   '마포구',
#   '-',
#   '강서구 소재 댄스교습시설 연관 병원',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10579</p>",
#   '38594',
#   '12.07.',
#   '타시도',
#   '-',
#   '강서구 소재 댄스교습시설 연관 병원',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10578</p>",
#   '38196',
#   '12.07.',
#   '송파구',
#   '-',
#   '종로구 소재 파고다타운 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10577</p>",
#   '38270',
#   '12.07.',
#   '영등포구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10576</p>",
#   '38543',
#   '12.07.',
#   '마포구',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10575</p>",
#   '38343',
#   '12.07.',
#   '마포구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10574</p>",
#   '38282',
#   '12.07.',
#   '성북구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10573</p>",
#   '38346',
#   '12.07.',
#   '중랑구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10572</p>",
#   '38310',
#   '12.07.',
#   '서대문구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10571</p>",
#   '38407',
#   '12.07.',
#   '은평구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10570</p>",
#   '38336',
#   '12.07.',
#   '양천구',
#   '-',
#   '타시도 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10569</p>",
#   '38321',
#   '12.07.',
#   '양천구',
#   '-',
#   '종로구 소재 파고다타운 관련',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10568</p>",
#   '38380',
#   '12.07.',
#   '양천구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10567</p>",
#   '38342',
#   '12.07.',
#   '서대문구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10566</p>",
#   '38191',
#   '12.07.',
#   '마포구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10565</p>",
#   '38193',
#   '12.07.',
#   '마포구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status2'></b>"],
#  ["<p class='corona19_no'>10564</p>",
#   '38306',
#   '12.07.',
#   '성동구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status2'></b>"]]

# %%
pd.DataFrame(data)
# Out:
#                                    0      1       2     3  4          5  \
# 0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -   감염경로 조사중
# 1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -   감염경로 조사중
# 2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -   감염경로 조사중
# 3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -   감염경로 조사중
# 4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -   감염경로 조사중
# ..                               ...    ...     ...   ... ..        ...
# 95  <p class='corona19_no'>10568</p>  38380  12.07.   양천구  -  기타 확진자 접촉
# 96  <p class='corona19_no'>10567</p>  38342  12.07.  서대문구  -   감염경로 조사중
# 97  <p class='corona19_no'>10566</p>  38191  12.07.   마포구  -  기타 확진자 접촉
# 98  <p class='corona19_no'>10565</p>  38193  12.07.   마포구  -   감염경로 조사중
# 99  <p class='corona19_no'>10564</p>  38306  12.07.   성동구  -  기타 확진자 접촉
#
#                           6
# 0          <b class=''></b>
# 1          <b class=''></b>
# 2          <b class=''></b>
# 3          <b class=''></b>
# 4          <b class=''></b>
# ..                      ...
# 95  <b class='status2'></b>
# 96  <b class='status2'></b>
# 97  <b class='status2'></b>
# 98  <b class='status2'></b>
# 99  <b class='status2'></b>
#
# [100 rows x 7 columns]

# %%
def get_seoul_covid19_100(page_no):
    
    """
    page_no : 입력값으로 페이지 번호를 입력하면 해당 번호의 데이터를 가져옴
    start_no : 입력받은 page_no로 시작 번호를 의미
    """
    start_no = (page_no - 1) * 100
    url = f"https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw={page_no}"
    url = f"{url}&order%5B0%5D%5Bdir%5D=desc&start={start_no}&length=100"
    
    response = requests.get(url)
    data_json = response.json()
    return data_json

# %%
# データがあるとき
get_seoul_covid19_100(2)
# Out:
# {'draw': 2,
#  'recordsTotal': 10663,
#  'recordsFiltered': 10663,
#  'data': [["<p class='corona19_no'>10563</p>",
#    '38355',
#    '12.07.',
#    '용산구',
#    '-',
#    '중구 소재 시장 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10562</p>",
#    '38202',
#    '12.07.',
#    '구로구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10561</p>",
#    '38176',
#    '12.07.',
#    '구로구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10560</p>",
#    '38482',
#    '12.07.',
#    '중랑구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10559</p>",
#    '38468',
#    '12.07.',
#    '중랑구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10558</p>",
#    '38459',
#    '12.07.',
#    '중랑구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10557</p>",
#    '38568',
#    '12.07.',
#    '송파구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10556</p>",
#    '38263',
#    '12.07.',
#    '동대문구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10555</p>",
#    '38410',
#    '12.07.',
#    '은평구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10554</p>",
#    '38391',
#    '12.07.',
#    '은평구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10553</p>",
#    '38392',
#    '12.07.',
#    '은평구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10552</p>",
#    '38408',
#    '12.07.',
#    '은평구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10551</p>",
#    '38252',
#    '12.07.',
#    '은평구',
#    '-',
#    '구로구 소재 보험회사 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10550</p>",
#    '38425',
#    '12.07.',
#    '관악구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10549</p>",
#    '38390',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10548</p>",
#    '38393',
#    '12.07.',
#    '관악구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10547</p>",
#    '38395',
#    '12.07.',
#    '관악구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10546</p>",
#    '38398',
#    '12.07.',
#    '관악구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10545</p>",
#    '38422',
#    '12.07.',
#    '관악구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10544</p>",
#    '38428',
#    '12.07.',
#    '관악구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10543</p>",
#    '38386',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10542</p>",
#    '38383',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10541</p>",
#    '38353',
#    '12.07.',
#    '타시도',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10540</p>",
#    '38377',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10539</p>",
#    '38375',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10538</p>",
#    '38366',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10537</p>",
#    '38472',
#    '12.07.',
#    '용산구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10536</p>",
#    '38360',
#    '12.07.',
#    '용산구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10535</p>",
#    '38316',
#    '12.07.',
#    '강남구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10534</p>",
#    '38400',
#    '12.07.',
#    '강남구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10533</p>",
#    '38319',
#    '12.07.',
#    '강남구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10532</p>",
#    '38332',
#    '12.07.',
#    '강남구',
#    '-',
#    '구로구소재 고등학교 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10531</p>",
#    '38388',
#    '12.07.',
#    '강남구',
#    '-',
#    '강남구 어학원 관련Ⅰ',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10530</p>",
#    '38592',
#    '12.07.',
#    '강남구',
#    '-',
#    '강남구 어학원 관련Ⅰ',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10529</p>",
#    '38187',
#    '12.07.',
#    '마포구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10528</p>",
#    '38186',
#    '12.07.',
#    '마포구',
#    '-',
#    '마포구 홈쇼핑회사 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10527</p>",
#    '38189',
#    '12.07.',
#    '마포구',
#    '-',
#    '마포구 홈쇼핑회사 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10526</p>",
#    '38455',
#    '12.07.',
#    '중랑구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10525</p>",
#    '38441',
#    '12.07.',
#    '중랑구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10524</p>",
#    '38329',
#    '12.07.',
#    '중랑구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10523</p>",
#    '38334',
#    '12.07.',
#    '중랑구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10522</p>",
#    '38402',
#    '12.07.',
#    '은평구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10521</p>",
#    '38557',
#    '12.07.',
#    '서초구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10520</p>",
#    '38350',
#    '12.07.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10519</p>",
#    '38274',
#    '12.07.',
#    '동대문구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10518</p>",
#    '38267',
#    '12.07.',
#    '노원구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10517</p>",
#    '38256',
#    '12.07.',
#    '노원구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10516</p>",
#    '38280',
#    '12.07.',
#    '노원구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10515</p>",
#    '38457',
#    '12.07.',
#    '노원구',
#    '-',
#    '종로구 소재 파고타타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10514</p>",
#    '38277',
#    '12.07.',
#    '노원구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10513</p>",
#    '38272',
#    '12.07.',
#    '노원구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10512</p>",
#    '38192',
#    '12.07.',
#    '구로구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10511</p>",
#    '38567',
#    '12.07.',
#    '송파구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10510</p>",
#    '38413',
#    '12.07.',
#    '기타',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10509</p>",
#    '38394',
#    '12.07.',
#    '은평구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10508</p>",
#    '38247',
#    '12.07.',
#    '종로구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10507</p>",
#    '38269',
#    '12.07.',
#    '양천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10506</p>",
#    '38255',
#    '12.07.',
#    '양천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10505</p>",
#    '38262',
#    '12.07.',
#    '양천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10504</p>",
#    '38275',
#    '12.07.',
#    '서대문구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10503</p>",
#    '38233',
#    '12.07.',
#    '서대문구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10502</p>",
#    '38359',
#    '12.07.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10501</p>",
#    '38354',
#    '12.07.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10500</p>",
#    '38271',
#    '12.07.',
#    '영등포구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10499</p>",
#    '38433',
#    '12.07.',
#    '중랑구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10498</p>",
#    '38290',
#    '12.07.',
#    '타시도',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10497</p>",
#    '38364',
#    '12.07.',
#    '서초구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10496</p>",
#    '38300',
#    '12.07.',
#    '은평구',
#    '-',
#    '중구 소재 시장 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10495</p>",
#    '38403',
#    '12.07.',
#    '은평구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10494</p>",
#    '38244',
#    '12.07.',
#    '종로구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10493</p>",
#    '38287',
#    '12.07.',
#    '광진구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10492</p>",
#    '38174',
#    '12.07.',
#    '구로구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10491</p>",
#    '38175',
#    '12.07.',
#    '구로구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10490</p>",
#    '38181',
#    '12.07.',
#    '구로구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10489</p>",
#    '38182',
#    '12.07.',
#    '구로구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10488</p>",
#    '38204',
#    '12.07.',
#    '강북구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10487</p>",
#    '38357',
#    '12.07.',
#    '양천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10486</p>",
#    '38415',
#    '12.07.',
#    '관악구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10485</p>",
#    '38409',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10484</p>",
#    '38405',
#    '12.07.',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10483</p>",
#    '38349',
#    '12.07.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10482</p>",
#    '38344',
#    '12.07.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10481</p>",
#    '38461',
#    '12.07.',
#    '성동구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10480</p>",
#    '38239',
#    '12.07.',
#    '도봉구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10479</p>",
#    '38484',
#    '12.07.',
#    '성북구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10478</p>",
#    '38483',
#    '12.07.',
#    '성북구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10477</p>",
#    '38194',
#    '12.07.',
#    '강북구',
#    '-',
#    '중랑구 실내 체육시설 Ⅱ 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10476</p>",
#    '38178',
#    '12.07.',
#    '강북구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10475</p>",
#    '38254',
#    '12.07.',
#    '양천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10474</p>",
#    '38179',
#    '12.07.',
#    '구로구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10473</p>",
#    '38351',
#    '12.07.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10472</p>",
#    '38320',
#    '12.07.',
#    '타시도',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10471</p>",
#    '38283',
#    '12.07.',
#    '광진구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10470</p>",
#    '38279',
#    '12.07.',
#    '광진구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10469</p>",
#    '38323',
#    '12.07.',
#    '강남구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10468</p>",
#    '38240',
#    '12.07.',
#    '강남구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10467</p>",
#    '38302',
#    '12.07.',
#    '성동구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10466</p>",
#    '38303',
#    '12.07.',
#    '금천구',
#    '-',
#    '구로구 소재 보험회사 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10465</p>",
#    '38314',
#    '12.07.',
#    '금천구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>10464</p>",
#    '38305',
#    '12.07.',
#    '금천구',
#    '-',
#    '종로구 소재 파고다타운 관련',
#    "<b class=''></b>"]]}

# %%
# データがないとき
get_seoul_covid19_100(1000)
# Out:
# {'draw': 1000, 'recordsTotal': 10663, 'recordsFiltered': 10663, 'data': []}

# %%
# 全体のデータを読み込む
# tqdm
#time.sleep で時間差をつくる
import time
# tqdm:進行の状態を表示するため
from tqdm import trange

# %%
for page_no in trange(1, 5):
    print(page_no)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 4004.11it/s]
# 1
# 2
# 3
# 4

# %%
# 確認のためテストで一部のデータを読み込む
page_list = []

all_page = 3
for page_no in trange(all_page + 1):
    one_page = get_seoul_covid19_100(page_no)
    one_page = pd.DataFrame(one_page["data"])
    page_list.append(one_page)
    
    #負荷を防ぐため0.5秒やすむ
    time.sleep(0.5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.03it/s]

# %%
page_list[:2]
# Out:
# [Empty DataFrame
#  Columns: []
#  Index: [],
#                                     0      1       2     3  4          5  \
#  0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -   감염경로 조사중
#  1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -   감염경로 조사중
#  2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -   감염경로 조사중
#  3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -   감염경로 조사중
#  4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -   감염경로 조사중
#  ..                               ...    ...     ...   ... ..        ...
#  95  <p class='corona19_no'>10568</p>  38380  12.07.   양천구  -  기타 확진자 접촉
#  96  <p class='corona19_no'>10567</p>  38342  12.07.  서대문구  -   감염경로 조사중
#  97  <p class='corona19_no'>10566</p>  38191  12.07.   마포구  -  기타 확진자 접촉
#  98  <p class='corona19_no'>10565</p>  38193  12.07.   마포구  -   감염경로 조사중
#  99  <p class='corona19_no'>10564</p>  38306  12.07.   성동구  -  기타 확진자 접촉
#
#                            6
#  0          <b class=''></b>
#  1          <b class=''></b>
#  2          <b class=''></b>
#  3          <b class=''></b>
#  4          <b class=''></b>
#  ..                      ...
#  95  <b class='status2'></b>
#  96  <b class='status2'></b>
#  97  <b class='status2'></b>
#  98  <b class='status2'></b>
#  99  <b class='status2'></b>
#
#  [100 rows x 7 columns]]

# %%
# データを読み込む
for page_no in trange(1,4):
    one_page = get_seoul_covid19_100(page_no)
    
    if len(one_page["data"]) > 0 :
        one_page = pd.DataFrame(one_page["data"])    
        page_list.append(one_page)
    
        #負荷を防ぐため0.5秒やすむ
        time.sleep(0.5)
    else:
        break
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:02<00:00,  1.05it/s]

# %%
page_list
# Out:
# [Empty DataFrame
#  Columns: []
#  Index: [],
#                                     0      1       2     3  4          5  \
#  0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -   감염경로 조사중
#  1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -   감염경로 조사중
#  2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -   감염경로 조사중
#  3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -   감염경로 조사중
#  4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -   감염경로 조사중
#  ..                               ...    ...     ...   ... ..        ...
#  95  <p class='corona19_no'>10568</p>  38380  12.07.   양천구  -  기타 확진자 접촉
#  96  <p class='corona19_no'>10567</p>  38342  12.07.  서대문구  -   감염경로 조사중
#  97  <p class='corona19_no'>10566</p>  38191  12.07.   마포구  -  기타 확진자 접촉
#  98  <p class='corona19_no'>10565</p>  38193  12.07.   마포구  -   감염경로 조사중
#  99  <p class='corona19_no'>10564</p>  38306  12.07.   성동구  -  기타 확진자 접촉
#
#                            6
#  0          <b class=''></b>
#  1          <b class=''></b>
#  2          <b class=''></b>
#  3          <b class=''></b>
#  4          <b class=''></b>
#  ..                      ...
#  95  <b class='status2'></b>
#  96  <b class='status2'></b>
#  97  <b class='status2'></b>
#  98  <b class='status2'></b>
#  99  <b class='status2'></b>
#
#  [100 rows x 7 columns],
#                                     0      1       2    3  4                5  \
#  0   <p class='corona19_no'>10563</p>  38355  12.07.  용산구  -      중구 소재 시장 관련
#  1   <p class='corona19_no'>10562</p>  38202  12.07.  구로구  -         감염경로 조사중
#  2   <p class='corona19_no'>10561</p>  38176  12.07.  구로구  -        기타 확진자 접촉
#  3   <p class='corona19_no'>10560</p>  38482  12.07.  중랑구  -         감염경로 조사중
#  4   <p class='corona19_no'>10559</p>  38468  12.07.  중랑구  -        기타 확진자 접촉
#  ..                               ...    ...     ...  ... ..              ...
#  95  <p class='corona19_no'>10468</p>  38240  12.07.  강남구  -         감염경로 조사중
#  96  <p class='corona19_no'>10467</p>  38302  12.07.  성동구  -        기타 확진자 접촉
#  97  <p class='corona19_no'>10466</p>  38303  12.07.  금천구  -   구로구 소재 보험회사 관련
#  98  <p class='corona19_no'>10465</p>  38314  12.07.  금천구  -  종로구 소재 파고다타운 관련
#  99  <p class='corona19_no'>10464</p>  38305  12.07.  금천구  -  종로구 소재 파고다타운 관련
#
#                     6
#  0   <b class=''></b>
#  1   <b class=''></b>
#  2   <b class=''></b>
#  3   <b class=''></b>
#  4   <b class=''></b>
#  ..               ...
#  95  <b class=''></b>
#  96  <b class=''></b>
#  97  <b class=''></b>
#  98  <b class=''></b>
#  99  <b class=''></b>
#
#  [100 rows x 7 columns],
#                                     0      1       2     3  4           5  \
#  0   <p class='corona19_no'>10463</p>  38238  12.07.   도봉구  -   기타 확진자 접촉
#  1   <p class='corona19_no'>10462</p>  38374  12.07.   은평구  -    감염경로 조사중
#  2   <p class='corona19_no'>10461</p>  38420  12.07.   동작구  -   기타 확진자 접촉
#  3   <p class='corona19_no'>10460</p>  38437  12.07.   동작구  -   기타 확진자 접촉
#  4   <p class='corona19_no'>10459</p>  38361  12.07.   동작구  -    감염경로 조사중
#  ..                               ...    ...     ...   ... ..         ...
#  95  <p class='corona19_no'>10368</p>  37874  12.06.   서초구  -    감염경로 조사중
#  96  <p class='corona19_no'>10367</p>  37605  12.06.   서초구  -   기타 확진자 접촉
#  97  <p class='corona19_no'>10366</p>  37604  12.06.   서초구  -   기타 확진자 접촉
#  98  <p class='corona19_no'>10365</p>  37628  12.06.  영등포구  -  타시도 확진자 접촉
#  99  <p class='corona19_no'>10364</p>  37714  12.06.  영등포구  -   기타 확진자 접촉
#
#                     6
#  0   <b class=''></b>
#  1   <b class=''></b>
#  2   <b class=''></b>
#  3   <b class=''></b>
#  4   <b class=''></b>
#  ..               ...
#  95  <b class=''></b>
#  96  <b class=''></b>
#  97  <b class=''></b>
#  98  <b class=''></b>
#  99  <b class=''></b>
#
#  [100 rows x 7 columns],
#                                     0      1       2     3  4          5  \
#  0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -   감염경로 조사중
#  1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -   감염경로 조사중
#  2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -   감염경로 조사중
#  3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -   감염경로 조사중
#  4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -   감염경로 조사중
#  ..                               ...    ...     ...   ... ..        ...
#  95  <p class='corona19_no'>10568</p>  38380  12.07.   양천구  -  기타 확진자 접촉
#  96  <p class='corona19_no'>10567</p>  38342  12.07.  서대문구  -   감염경로 조사중
#  97  <p class='corona19_no'>10566</p>  38191  12.07.   마포구  -  기타 확진자 접촉
#  98  <p class='corona19_no'>10565</p>  38193  12.07.   마포구  -   감염경로 조사중
#  99  <p class='corona19_no'>10564</p>  38306  12.07.   성동구  -  기타 확진자 접촉
#
#                            6
#  0          <b class=''></b>
#  1          <b class=''></b>
#  2          <b class=''></b>
#  3          <b class=''></b>
#  4          <b class=''></b>
#  ..                      ...
#  95  <b class='status2'></b>
#  96  <b class='status2'></b>
#  97  <b class='status2'></b>
#  98  <b class='status2'></b>
#  99  <b class='status2'></b>
#
#  [100 rows x 7 columns],
#                                     0      1       2    3  4                5  \
#  0   <p class='corona19_no'>10563</p>  38355  12.07.  용산구  -      중구 소재 시장 관련
#  1   <p class='corona19_no'>10562</p>  38202  12.07.  구로구  -         감염경로 조사중
#  2   <p class='corona19_no'>10561</p>  38176  12.07.  구로구  -        기타 확진자 접촉
#  3   <p class='corona19_no'>10560</p>  38482  12.07.  중랑구  -         감염경로 조사중
#  4   <p class='corona19_no'>10559</p>  38468  12.07.  중랑구  -        기타 확진자 접촉
#  ..                               ...    ...     ...  ... ..              ...
#  95  <p class='corona19_no'>10468</p>  38240  12.07.  강남구  -         감염경로 조사중
#  96  <p class='corona19_no'>10467</p>  38302  12.07.  성동구  -        기타 확진자 접촉
#  97  <p class='corona19_no'>10466</p>  38303  12.07.  금천구  -   구로구 소재 보험회사 관련
#  98  <p class='corona19_no'>10465</p>  38314  12.07.  금천구  -  종로구 소재 파고다타운 관련
#  99  <p class='corona19_no'>10464</p>  38305  12.07.  금천구  -  종로구 소재 파고다타운 관련
#
#                     6
#  0   <b class=''></b>
#  1   <b class=''></b>
#  2   <b class=''></b>
#  3   <b class=''></b>
#  4   <b class=''></b>
#  ..               ...
#  95  <b class=''></b>
#  96  <b class=''></b>
#  97  <b class=''></b>
#  98  <b class=''></b>
#  99  <b class=''></b>
#
#  [100 rows x 7 columns],
#                                     0      1       2     3  4           5  \
#  0   <p class='corona19_no'>10463</p>  38238  12.07.   도봉구  -   기타 확진자 접촉
#  1   <p class='corona19_no'>10462</p>  38374  12.07.   은평구  -    감염경로 조사중
#  2   <p class='corona19_no'>10461</p>  38420  12.07.   동작구  -   기타 확진자 접촉
#  3   <p class='corona19_no'>10460</p>  38437  12.07.   동작구  -   기타 확진자 접촉
#  4   <p class='corona19_no'>10459</p>  38361  12.07.   동작구  -    감염경로 조사중
#  ..                               ...    ...     ...   ... ..         ...
#  95  <p class='corona19_no'>10368</p>  37874  12.06.   서초구  -    감염경로 조사중
#  96  <p class='corona19_no'>10367</p>  37605  12.06.   서초구  -   기타 확진자 접촉
#  97  <p class='corona19_no'>10366</p>  37604  12.06.   서초구  -   기타 확진자 접촉
#  98  <p class='corona19_no'>10365</p>  37628  12.06.  영등포구  -  타시도 확진자 접촉
#  99  <p class='corona19_no'>10364</p>  37714  12.06.  영등포구  -   기타 확진자 접촉
#
#                     6
#  0   <b class=''></b>
#  1   <b class=''></b>
#  2   <b class=''></b>
#  3   <b class=''></b>
#  4   <b class=''></b>
#  ..               ...
#  95  <b class=''></b>
#  96  <b class=''></b>
#  97  <b class=''></b>
#  98  <b class=''></b>
#  99  <b class=''></b>
#
#  [100 rows x 7 columns]]

# %%
pd.concat(page_list)
# Out:
#                                    0      1       2     3  4           5  \
# 0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -    감염경로 조사중
# 1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -    감염경로 조사중
# 2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -    감염경로 조사중
# 3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -    감염경로 조사중
# 4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -    감염경로 조사중
# ..                               ...    ...     ...   ... ..         ...
# 95  <p class='corona19_no'>10368</p>  37874  12.06.   서초구  -    감염경로 조사중
# 96  <p class='corona19_no'>10367</p>  37605  12.06.   서초구  -   기타 확진자 접촉
# 97  <p class='corona19_no'>10366</p>  37604  12.06.   서초구  -   기타 확진자 접촉
# 98  <p class='corona19_no'>10365</p>  37628  12.06.  영등포구  -  타시도 확진자 접촉
# 99  <p class='corona19_no'>10364</p>  37714  12.06.  영등포구  -   기타 확진자 접촉
#
#                    6
# 0   <b class=''></b>
# 1   <b class=''></b>
# 2   <b class=''></b>
# 3   <b class=''></b>
# 4   <b class=''></b>
# ..               ...
# 95  <b class=''></b>
# 96  <b class=''></b>
# 97  <b class=''></b>
# 98  <b class=''></b>
# 99  <b class=''></b>
#
# [600 rows x 7 columns]

# %%
def get_multi_page_list(start_page, end_page):
    
    page_list = []
    
    for page_no in trange(start_page, end_page + 1):
        one_page = get_seoul_covid19_100(page_no)
    
        if len(one_page["data"]) > 0:
            one_page = pd.DataFrame(one_page["data"])    
            page_list.append(one_page)
    
            #負荷を防ぐため0.5秒やすむ
            time.sleep(0.5)
        else:
            
            return page_list
    return page_list

# %%
end_page
# Out:
# 108

# %%
start_page = 1
end_page = 30
page_list = get_multi_page_list(start_page,end_page)
page_list[:1]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:37<00:00,  1.25s/it]
# [                                   0      1       2     3  4          5  \
#  0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -   감염경로 조사중
#  1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -   감염경로 조사중
#  2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -   감염경로 조사중
#  3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -   감염경로 조사중
#  4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -   감염경로 조사중
#  ..                               ...    ...     ...   ... ..        ...
#  95  <p class='corona19_no'>10568</p>  38380  12.07.   양천구  -  기타 확진자 접촉
#  96  <p class='corona19_no'>10567</p>  38342  12.07.  서대문구  -   감염경로 조사중
#  97  <p class='corona19_no'>10566</p>  38191  12.07.   마포구  -  기타 확진자 접촉
#  98  <p class='corona19_no'>10565</p>  38193  12.07.   마포구  -   감염경로 조사중
#  99  <p class='corona19_no'>10564</p>  38306  12.07.   성동구  -  기타 확진자 접촉
#
#                            6
#  0          <b class=''></b>
#  1          <b class=''></b>
#  2          <b class=''></b>
#  3          <b class=''></b>
#  4          <b class=''></b>
#  ..                      ...
#  95  <b class='status2'></b>
#  96  <b class='status2'></b>
#  97  <b class='status2'></b>
#  98  <b class='status2'></b>
#  99  <b class='status2'></b>
#
#  [100 rows x 7 columns]]

# %%
df_all = pd.concat(page_list)
df_all
# Out:
#                                    0      1       2     3  4              5  \
# 0   <p class='corona19_no'>10663</p>  38379  12.07.   양천구  -       감염경로 조사중
# 1   <p class='corona19_no'>10662</p>  38370  12.07.   강서구  -       감염경로 조사중
# 2   <p class='corona19_no'>10661</p>  38419  12.07.   강서구  -       감염경로 조사중
# 3   <p class='corona19_no'>10660</p>  38418  12.07.   강서구  -       감염경로 조사중
# 4   <p class='corona19_no'>10659</p>  38558  12.07.   광진구  -       감염경로 조사중
# ..                               ...    ...     ...   ... ..            ...
# 95   <p class='corona19_no'>7668</p>  31111  11.23.   강남구  -    서초구 사우나Ⅱ 관련
# 96   <p class='corona19_no'>7667</p>  31070  11.23.  영등포구  -       감염경로 조사중
# 97   <p class='corona19_no'>7666</p>  31117  11.23.   동작구  -  동작구 임용단기학원 관련
# 98   <p class='corona19_no'>7665</p>  31079  11.23.   도봉구  -       감염경로 조사중
# 99   <p class='corona19_no'>7664</p>  31128  11.23.   서초구  -    서초구 사우나Ⅱ 관련
#
#                             6
# 0            <b class=''></b>
# 1            <b class=''></b>
# 2            <b class=''></b>
# 3            <b class=''></b>
# 4            <b class=''></b>
# ..                        ...
# 95  <b class='status1'>퇴원</b>
# 96    <b class='status1'></b>
# 97    <b class='status1'></b>
# 98    <b class='status1'></b>
# 99    <b class='status1'></b>
#
# [3000 rows x 7 columns]

# %%
cols = df.columns.tolist()

# %%
df_all.columns = cols

# %%
df_all.head()
# Out:
#                                  연번     환자     확진일  거주지 여행력       접촉력  \
# 0  <p class='corona19_no'>10663</p>  38379  12.07.  양천구   -  감염경로 조사중
# 1  <p class='corona19_no'>10662</p>  38370  12.07.  강서구   -  감염경로 조사중
# 2  <p class='corona19_no'>10661</p>  38419  12.07.  강서구   -  감염경로 조사중
# 3  <p class='corona19_no'>10660</p>  38418  12.07.  강서구   -  감염경로 조사중
# 4  <p class='corona19_no'>10659</p>  38558  12.07.  광진구   -  감염경로 조사중
#
#                퇴원현황
# 0  <b class=''></b>
# 1  <b class=''></b>
# 2  <b class=''></b>
# 3  <b class=''></b>
# 4  <b class=''></b>

# %%
df_all.shape
# Out:
# (3000, 7)

# %% [markdown]
# # データ前処理

# %% [markdown]
# * 연번, 퇴원현황

# %%
import re
def extract_number(num_string):
    if type(num_string) == str:
        num_string = num_string.replace("corona19", "")
        num = re.sub("[^0-9]", "", num_string)
        num = int(num)
        return num
    else:
        return num_string

# %%
num_string = "<p class='corona19_no'>10660</p>"
extract_number(num_string)
# Out:
# 10660

# %%
df_all["연번"] = df_all["연번"].map(extract_number)

# %%
df_all["연번"].head()
# Out:
# 0    10663
# 1    10662
# 2    10661
# 3    10660
# 4    10659
# Name: 연번, dtype: int64

# %%
def extract_hangeul(origin_text):
    subtract_text = re.sub("[^가-힣]","",origin_text)
    return subtract_text

# %%
origin_text = "<b class=''>퇴원</b>"
extract_hangeul(origin_text)
# Out:
# '퇴원'

# %%
# str.containsの方法もある

# %%
df_all["퇴원현황"].value_counts()
# Out:
# <b class=''></b>             2117
# <b class='status1'></b>       550
# <b class='status2'></b>       241
# <b class='status1'>퇴원</b>      84
# <b class='status2'>사망</b>       8
# Name: 퇴원현황, dtype: int64

# %%
df_all.loc[df_all["퇴원현황"].str.contains("퇴원"),"퇴원현황"] = "퇴원"
df_all.loc[df_all["퇴원현황"].str.contains("사망"),"퇴원현황"] = "사망"
df_all.loc[~df_all["퇴원현황"].str.contains("퇴원|사망"),"퇴원현황"] = np.nan

# %%
df_all["퇴원현황"]
# Out:
# '사망'

# %%
df_all["퇴원현황"].value_counts()
# Out:
# 퇴원    84
# 사망     8
# Name: 퇴원현황, dtype: int64

# %%
last_date = df_all.iloc[0]["확진일"]

# %%
date  = last_date.replace(".", "_")
date
# Out:
# '12_07_'

# %%
# df_all["퇴원현황"] = df_all["퇴원현황"].map(extract_hangeul)

# %%
# df_all["퇴원현황"].head()

# %%
# Save file
file_name = f"seoul-covid19-{date}.csv"
file_name
# Out:
# 'seoul-covid19-12_07_.csv'

# %%
df_all.to_csv(file_name,index=False)

# %%
pd.read_csv(file_name)
# Out:
#          연번       환자     확진일   거주지 여행력            접촉력 퇴원현황
# 0     10663  38379.0  12.07.   양천구   -       감염경로 조사중  NaN
# 1     10662  38370.0  12.07.   강서구   -       감염경로 조사중  NaN
# 2     10661  38419.0  12.07.   강서구   -       감염경로 조사중  NaN
# 3     10660  38418.0  12.07.   강서구   -       감염경로 조사중  NaN
# 4     10659  38558.0  12.07.   광진구   -       감염경로 조사중  NaN
# ...     ...      ...     ...   ...  ..            ...  ...
# 2995   7668  31111.0  11.23.   강남구   -    서초구 사우나Ⅱ 관련   퇴원
# 2996   7667  31070.0  11.23.  영등포구   -       감염경로 조사중  NaN
# 2997   7666  31117.0  11.23.   동작구   -  동작구 임용단기학원 관련  NaN
# 2998   7665  31079.0  11.23.   도봉구   -       감염경로 조사중  NaN
# 2999   7664  31128.0  11.23.   서초구   -    서초구 사우나Ⅱ 관련  NaN
#
# [3000 rows x 7 columns]
